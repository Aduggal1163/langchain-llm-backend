# %%
#for chat conversation
from langchain_ollama import ChatOllama
#initialize the model
llm = ChatOllama(
    model='llama3.2:1b',
    temperature=0
)
response = llm.invoke("Explain full stack development")
print(response.content)
# Out:
# f:\Tasks\langchain\langchain_env\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# Full-stack development is the process of building an application or website that has both front-end and back-end components. It involves designing, developing, testing, and deploying a complete software system from scratch.
#
# **Front-end Development**
#
# The front-end refers to the client-side of the application, which includes:
#
# 1. User Interface (UI) design: Creating the visual layout and user experience of the application.
# 2. Front-end framework: Using a programming language like JavaScript, HTML, CSS, or React to build the UI components.
# 3. Client-side logic: Writing code that runs on the client's web browser to handle events, validate user input, and perform calculations.
#
# Front-end developers typically work with:
#
# * HTML (Hypertext Markup Language)
# * CSS (Cascading Style Sheets)
# * JavaScript
# * Front-end frameworks like React, Angular, or Vue.js
#
# **Back-end Development**
#
# The back-end refers to the server-side of the application, which includes:
#
# 1. Server-side programming: Writing code that runs on a web server to handle requests and responses.
# 2. Database management: Interacting with databases to store and retrieve data.
# 3. API design: Creating RESTful APIs (Representational State of Resource) to expose data and functionality.
#
# Back-end developers typically work with:
#
# * Programming languages like Java, Python, Ruby, or PHP
# * Server-side frameworks like Node.js, Django, or Ruby on Rails
# * Database management systems like MySQL, PostgreSQL, or MongoDB
#
# **Full-stack Development**
#
# To build a full-stack application, you need to have both front-end and back-end skills. Here's an overview of the process:
#
# 1. **Design**: Define the UI and user experience using design tools like Sketch, Figma, or Adobe XD.
# 2. **Front-end development**: Build the client-side components using HTML, CSS, JavaScript, and a front-end framework.
# 3. **Back-end development**: Set up the server-side infrastructure using a programming language and a back-end framework.
# 4. **API integration**: Integrate APIs to expose data and functionality between the front-end and back-end.
# 5. **Testing**: Write unit tests, integration tests, and end-to-end tests to ensure the application works as expected.
# 6. **Deployment**: Deploy the full-stack application to a production environment using a containerization platform like Docker or a cloud provider like AWS.
#
# **Benefits of Full-stack Development**
#
# 1. **Improved productivity**: By having both front-end and back-end skills, you can work on multiple aspects of an application simultaneously.
# 2. **Increased flexibility**: You can make changes to the front-end without affecting the back-end, and vice versa.
# 3. **Better collaboration**: Front-end developers can collaborate with back-end developers to ensure a seamless user experience.
#
# **Challenges of Full-stack Development**
#
# 1. **Steeper learning curve**: Full-stack development requires a broad range of skills, which can be overwhelming for beginners.
# 2. **Increased complexity**: Managing multiple technologies and frameworks can lead to increased complexity and maintenance costs.
# 3. **Higher risk of errors**: With both front-end and back-end components, there's a higher risk of errors or bugs that can affect the entire application.
#
# In summary, full-stack development is a powerful approach to building complex applications, but it requires careful planning, coordination, and execution. By understanding the benefits and challenges of full-stack development, you can make informed decisions about your project and achieve success in the world of software development.

# %%
#For non chat execution
from langchain_ollama import OllamaLLM
llm = OllamaLLM(model = 'llama3.2:1b')
response = llm.invoke("The capital of India is")
print(response)
# Out:
# The capital of India is New Delhi.
