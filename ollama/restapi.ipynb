# %% [markdown]
# Generate using Ollama library

# %%
import ollama
response = ollama.generate(
    model='llama3.2:1b',
    prompt="Explain AI"
)
print(response.response)
# Out:
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and perception. The goal of AI is to create machines that can think, learn, and act like humans, but with some key differences.
#
# There are several types of AI, including:
#
# 1. Narrow or Weak AI: This type of AI is designed to perform a specific task, such as image recognition, speech recognition, or playing chess. Narrow AI systems use algorithms and data to make decisions, but they do not have the ability to generalize to new situations or learn from experience.
# 2. General or Strong AI: This type of AI aims to create machines that can think and behave like humans in general, rather than just a specific task. General AI would be able to reason, learn, and apply knowledge across a wide range of tasks and domains.
#
# AI is based on several key technologies, including:
#
# 1. Machine Learning (ML): ML is a subset of AI that involves training algorithms to make predictions or take actions based on data. There are several types of ML, including supervised learning, unsupervised learning, and reinforcement learning.
# 2. Deep Learning: This type of ML uses neural networks with multiple layers to analyze and interpret complex data. Deep learning has been particularly successful in image recognition, speech recognition, and natural language processing tasks.
# 3. Natural Language Processing (NLP): NLP is the study of how humans communicate and process language. AI-powered NLP systems can understand and generate human-like text, speech, and sentiment.
#
# AI applications include:
#
# 1. Virtual assistants: Siri, Google Assistant, and Alexa are examples of virtual assistants that use AI to answer questions, perform tasks, and control smart home devices.
# 2. Image recognition: AI-powered image recognition systems are used in self-driving cars, facial recognition software, and medical diagnosis.
# 3. Predictive maintenance: AI-powered predictive maintenance systems can analyze data from sensors and machines to predict when they will fail or require repair.
# 4. Personalized recommendations: AI can be used to personalize content, products, and services based on user behavior and preferences.
#
# AI has many benefits, including:
#
# 1. Improved accuracy: AI can perform tasks more accurately and quickly than humans, which can lead to improved productivity and efficiency.
# 2. Enhanced decision-making: AI can analyze large amounts of data and make decisions based on that analysis, which can help organizations make better-informed decisions.
# 3. Increased safety: AI can be used to predict and prevent accidents, such as in the case of self-driving cars.
#
# However, AI also raises several concerns, including:
#
# 1. Job displacement: AI could potentially displace human workers, particularly those in jobs that involve repetitive or routine tasks.
# 2. Bias and fairness: AI systems can perpetuate existing biases and inequalities if they are trained on biased data or designed with a particular worldview.
# 3. Security risks: AI-powered systems can be vulnerable to cyber attacks and have security risks if not properly designed and implemented.
#
# Overall, AI is a powerful technology that has the potential to transform many aspects of our lives, but it requires careful consideration of its potential benefits and drawbacks.

# %% [markdown]
# Generate using Rest API

# %%
import requests
import json
url = 'http://localhost:11434/api/generate'
payload = {
    'model':'llama3.2:1b',
    'prompt':'explain ai'
}
response = requests.post(url,json=payload)

# %%
response
# Out:
# <Response [200]>

# %%
for i in response.iter_lines():
    print(i)
# Out:
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.1522585Z","response":"Art","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.2805989Z","response":"ificial","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.2901815Z","response":" Intelligence","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.299456Z","response":" (","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3089814Z","response":"AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3182362Z","response":")","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3273843Z","response":" refers","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3363288Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3454575Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3551609Z","response":" development","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.363905Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3731455Z","response":" computer","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3822528Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.3914183Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.400575Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.409532Z","response":" perform","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4191685Z","response":" tasks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4278468Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4370871Z","response":" typically","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4468364Z","response":" require","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4559776Z","response":" human","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4654794Z","response":" intelligence","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4747106Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4837558Z","response":" such","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.4927462Z","response":" as","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5021658Z","response":" learning","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5112131Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.520155Z","response":" problem","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5289038Z","response":"-solving","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5386917Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5471794Z","response":" decision","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5567199Z","response":"-making","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5657411Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5745744Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5773296Z","response":" perception","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.5924384Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6012683Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6099478Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6185473Z","response":" use","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6277486Z","response":" algorithms","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6367237Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6450536Z","response":" data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6541524Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6632171Z","response":" make","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6717451Z","response":" decisions","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.680422Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6896795Z","response":" predictions","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.6986664Z","response":" without","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7071742Z","response":" being","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7162887Z","response":" explicitly","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7258454Z","response":" programmed","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7348617Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7434825Z","response":"There","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7524277Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7612449Z","response":" several","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7698657Z","response":" types","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7795152Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7887322Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.7978573Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8075286Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8166609Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.825072Z","response":"1","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8345348Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8435812Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.852473Z","response":"N","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8614427Z","response":"arrow","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8708149Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.879305Z","response":" Weak","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8883336Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.8973047Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9064931Z","response":" Designed","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9154728Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9242268Z","response":" perform","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9330731Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9423586Z","response":" specific","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9507774Z","response":" task","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9600622Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9690888Z","response":" such","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9774816Z","response":" as","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9863752Z","response":" facial","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:22.9953464Z","response":" recognition","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.004367Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0129432Z","response":" language","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0221233Z","response":" translation","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0306029Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0393268Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0480991Z","response":" playing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0573666Z","response":" chess","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0660961Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0751207Z","response":"2","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0837488Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.0927573Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1013634Z","response":"General","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.110611Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1197428Z","response":" Strong","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1285611Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1378207Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1467966Z","response":" A","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.155837Z","response":" hypothetical","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1643898Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.173103Z","response":" system","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1824233Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.1915113Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2003509Z","response":" perform","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2089299Z","response":" any","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2179431Z","response":" intellectual","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2268221Z","response":" task","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2357084Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2450438Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2537015Z","response":" human","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2626077Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2712465Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2804817Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2895486Z","response":" learning","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.2982494Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3069986Z","response":" reasoning","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3165401Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3257438Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3346763Z","response":" problem","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3438297Z","response":"-solving","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3529295Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3617071Z","response":"3","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3704908Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3792338Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3880887Z","response":"Super","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.3977236Z","response":"intelligence","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4060827Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4151044Z","response":" An","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4244057Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4333044Z","response":" system","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4421724Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4507437Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4599737Z","response":" significantly","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4685637Z","response":" more","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4775265Z","response":" intelligent","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4865318Z","response":" than","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.4957485Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5043826Z","response":" best","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5134665Z","response":" human","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5222565Z","response":" minds","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5313709Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5401667Z","response":"AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5491089Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5580372Z","response":" use","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.566952Z","response":" various","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5753985Z","response":" techniques","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5846405Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.5938996Z","response":" achieve","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6027357Z","response":" their","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6115965Z","response":" goals","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6202601Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6293773Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6385296Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6474291Z","response":"1","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6566111Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6654727Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6742249Z","response":"Machine","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6831794Z","response":" Learning","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.6917204Z","response":" (","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7003474Z","response":"ML","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7092429Z","response":")**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7195246Z","response":":","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7281495Z","response":" A","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7371068Z","response":" subset","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7458166Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7547395Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7637339Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7729433Z","response":" enables","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7816953Z","response":" machines","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.7904224Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.799096Z","response":" learn","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8082531Z","response":" from","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8172717Z","response":" data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8264988Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8357164Z","response":" improve","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8449878Z","response":" their","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8536754Z","response":" performance","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8626966Z","response":" over","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8713924Z","response":" time","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8802924Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8894383Z","response":"2","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.8986237Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.907337Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9159052Z","response":"Deep","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9251085Z","response":" Learning","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.934214Z","response":" (","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9431776Z","response":"DL","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9519081Z","response":")**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9612865Z","response":":","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9695842Z","response":" A","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.978403Z","response":" type","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9874932Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:23.9964322Z","response":" ML","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0054732Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0141003Z","response":" uses","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0231861Z","response":" neural","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0324431Z","response":" networks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.041175Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0502455Z","response":" analyze","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0587396Z","response":" complex","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0676864Z","response":" data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0763663Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0855223Z","response":" make","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.0941566Z","response":" predictions","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1030684Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.111476Z","response":" decisions","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1205582Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1295907Z","response":"3","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1385757Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1476639Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1563799Z","response":"Natural","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1653831Z","response":" Language","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1741674Z","response":" Processing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1830467Z","response":" (","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.1919061Z","response":"N","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2008142Z","response":"LP","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2090251Z","response":")**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2181968Z","response":":","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2271999Z","response":" The","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2357838Z","response":" ability","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.244997Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2536434Z","response":" computers","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2624099Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2714492Z","response":" understand","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2799926Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2890815Z","response":" interpret","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.2977309Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3071539Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3163253Z","response":" generate","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3255648Z","response":" human","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3354214Z","response":" language","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3444073Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3490819Z","response":"AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3625458Z","response":" technologies","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3714523Z","response":" have","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3803657Z","response":" numerous","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.389588Z","response":" applications","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.3983313Z","response":" across","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4071498Z","response":" various","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.415931Z","response":" industries","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4252161Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4340664Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4429142Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4520351Z","response":"1","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4610408Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4700701Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.479045Z","response":"Virtual","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4880392Z","response":" Assist","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.4968292Z","response":"ants","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5059529Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.514652Z","response":" Siri","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5234197Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5323377Z","response":" Google","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5417233Z","response":" Assistant","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5501358Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5592391Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5683382Z","response":" Alexa","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5771171Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5857738Z","response":" examples","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.5946536Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6034609Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6125702Z","response":"-powered","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6215207Z","response":" virtual","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6308574Z","response":" assistants","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.639556Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6483241Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6575228Z","response":" perform","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6661733Z","response":" tasks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6754246Z","response":" such","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6841939Z","response":" as","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.6933855Z","response":" setting","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7018035Z","response":" reminders","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7113856Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7199451Z","response":" sending","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7291117Z","response":" messages","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7382329Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7471737Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7557396Z","response":" making","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7647442Z","response":" calls","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7740261Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7825552Z","response":"2","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.7914845Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8010273Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8101189Z","response":"Image","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8187272Z","response":" Recognition","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8281236Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.837488Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8466116Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8553654Z","response":" like","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8647606Z","response":" Facebook","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8736773Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8822449Z","response":" facial","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.8915874Z","response":" recognition","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9003669Z","response":" technology","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9095022Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9188447Z","response":" Google","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9276158Z","response":" Photos","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9365475Z","response":"\'","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9461688Z","response":" automatic","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9548536Z","response":" object","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9640283Z","response":" detection","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.972681Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9818924Z","response":" identify","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.990496Z","response":" objects","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:24.9994168Z","response":" within","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0087037Z","response":" images","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0175156Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0261456Z","response":"3","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0351503Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.044069Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0528949Z","response":"Predict","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0620189Z","response":"ive","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.071065Z","response":" Analytics","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0798627Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0886553Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.0973735Z","response":"-powered","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1065103Z","response":" tools","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1154107Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1239723Z","response":" analyze","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1335816Z","response":" data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.142704Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1516047Z","response":" predict","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1602336Z","response":" customer","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1689857Z","response":" behavior","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1781332Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1869549Z","response":" detect","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.1961276Z","response":" anomalies","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2050009Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2141187Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2230517Z","response":" make","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2315593Z","response":" recommendations","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2403524Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2491751Z","response":"4","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.258886Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2679381Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2770425Z","response":"Robot","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2860303Z","response":"ics","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.2955059Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3042408Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3128958Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3219108Z","response":" used","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3309859Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3398797Z","response":" robots","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3492043Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3582345Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3671654Z","response":" perform","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3759219Z","response":" tasks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3853229Z","response":" such","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.3943012Z","response":" as","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4032692Z","response":" assembly","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.41246Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4214419Z","response":" navigation","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4303474Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.439836Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4488559Z","response":" control","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4580271Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4674687Z","response":"However","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4762909Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4851977Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.4943311Z","response":" also","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5034771Z","response":" raises","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5124387Z","response":" several","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5213081Z","response":" concerns","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5298763Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5394196Z","response":" including","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5482733Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5570014Z","response":"1","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5661506Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5749374Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5837939Z","response":"Job","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.5933276Z","response":" Dis","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6022419Z","response":"placement","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6111352Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.620612Z","response":" As","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6291399Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6328755Z","response":" takes","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6471966Z","response":" over","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6563461Z","response":" routine","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6652027Z","response":" tasks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6736161Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6829277Z","response":" some","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.6917795Z","response":" jobs","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.700831Z","response":" may","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7100778Z","response":" become","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7189985Z","response":" obsolete","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7276781Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7366279Z","response":" leading","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7461185Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7550325Z","response":" significant","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.763739Z","response":" economic","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7734041Z","response":" disruption","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7822734Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.7913394Z","response":"2","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8009429Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8097231Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8191769Z","response":"Bias","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8284243Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8377521Z","response":" Fair","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8466772Z","response":"ness","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8563077Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8652075Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8745129Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8836665Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.8928031Z","response":" perpet","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9015315Z","response":"uate","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9103583Z","response":" biases","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9191798Z","response":" if","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9280084Z","response":" they","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9369302Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9464796Z","response":" trained","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9551929Z","response":" on","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9639299Z","response":" biased","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9730633Z","response":" data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9818799Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9907338Z","response":" designed","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:25.9995419Z","response":" with","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0089636Z","response":" specific","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0179515Z","response":" objectives","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0268175Z","response":" in","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0361458Z","response":" mind","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0452146Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0538291Z","response":"3","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0630557Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0720473Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0805839Z","response":"Security","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0895145Z","response":" Ris","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.0988723Z","response":"ks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1078204Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1170693Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1261729Z","response":"-powered","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1351111Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1441649Z","response":" can","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1531383Z","response":" be","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1620691Z","response":" vulnerable","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1709217Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1802022Z","response":" cyber","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1890098Z","response":" attacks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.1981251Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2067771Z","response":" which","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2157306Z","response":" could","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.224958Z","response":" have","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2336913Z","response":" severe","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2422756Z","response":" consequences","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2518635Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2607879Z","response":"To","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2699617Z","response":" address","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2788182Z","response":" these","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2877949Z","response":" concerns","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.2965928Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3054331Z","response":" researchers","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3152865Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3240269Z","response":" developers","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3328631Z","response":" are","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3426926Z","response":" working","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3516439Z","response":" on","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3610194Z","response":" developing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3696826Z","response":":\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3786365Z","response":"1","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3875165Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.3968377Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4057419Z","response":"Ex","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4150358Z","response":"plain","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4242157Z","response":"able","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4328789Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4422952Z","response":" (","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4507Z","response":"X","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.459806Z","response":"AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4691305Z","response":")**","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4783141Z","response":":","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4868718Z","response":" Techniques","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.4964374Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5053448Z","response":" help","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5141476Z","response":" humans","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5232168Z","response":" understand","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5321672Z","response":" how","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5406802Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5498945Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5592632Z","response":" make","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5655662Z","response":" decisions","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5767325Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5858226Z","response":" predictions","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.5944954Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.603894Z","response":"2","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6135389Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6223164Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6311193Z","response":"Ad","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6418885Z","response":"vers","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6508858Z","response":"arial","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6597827Z","response":" Training","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6687032Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6777788Z","response":" Methods","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6869084Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.6961522Z","response":" teach","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7051207Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7137957Z","response":" systems","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7230845Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7320371Z","response":" recognize","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7412587Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7502981Z","response":" respond","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.759418Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.768446Z","response":" malicious","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7777351Z","response":" inputs","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7869667Z","response":" or","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.7964083Z","response":" attacks","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8055154Z","response":".\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8149208Z","response":"3","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8240827Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8327465Z","response":" **","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8423987Z","response":"D","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8518989Z","response":"iverse","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.860436Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8697911Z","response":" Representative","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8790051Z","response":" Data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8876885Z","response":"**:","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.8973913Z","response":" Strategies","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9061424Z","response":" that","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9151195Z","response":" ensure","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9243474Z","response":" data","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9331787Z","response":" is","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9427066Z","response":" diverse","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9512806Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9611011Z","response":" representative","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9699059Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9783658Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9880986Z","response":" free","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:26.9971287Z","response":" from","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0059835Z","response":" biases","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0152292Z","response":".\\n\\n","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0245086Z","response":"Overall","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.033239Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0420101Z","response":" AI","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0514658Z","response":" has","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0602406Z","response":" the","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0688297Z","response":" potential","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0782542Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0873862Z","response":" revolution","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.0959604Z","response":"ize","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1052199Z","response":" various","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1146079Z","response":" aspects","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1233595Z","response":" of","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1322451Z","response":" our","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1417258Z","response":" lives","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.151125Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1597452Z","response":" but","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1690811Z","response":" it","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1782419Z","response":"\'s","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1867383Z","response":" essential","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.1964181Z","response":" to","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2056997Z","response":" approach","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2142986Z","response":" its","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2239083Z","response":" development","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2328648Z","response":" with","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2418394Z","response":" caution","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2511172Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2601393Z","response":" accountability","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2692882Z","response":",","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2784212Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2875854Z","response":" a","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.2964304Z","response":" focus","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.3054744Z","response":" on","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.3146942Z","response":" addressing","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.3241438Z","response":" its","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.3337002Z","response":" limitations","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.3432289Z","response":" and","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.3529017Z","response":" challenges","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.362614Z","response":".","done":false}'
# b'{"model":"llama3.2:1b","created_at":"2026-02-23T09:26:27.371843Z","response":"","done":true,"done_reason":"stop","context":[128006,9125,128007,271,38766,1303,33025,2696,25,6790,220,2366,18,271,128009,128006,882,128007,271,95444,16796,128009,128006,78191,128007,271,9470,16895,22107,320,15836,8,19813,311,279,4500,315,6500,6067,430,649,2804,9256,430,11383,1397,3823,11478,11,1778,439,6975,11,3575,99246,11,5597,28846,11,323,21063,13,15592,6067,1005,26249,323,828,311,1304,11429,477,20492,2085,1694,21650,56168,382,3947,527,3892,4595,315,15592,11,2737,1473,16,13,3146,45,6172,477,42264,15592,96618,48525,311,2804,264,3230,3465,11,1778,439,28900,18324,11,4221,14807,11,477,5737,33819,627,17,13,3146,15777,477,27191,15592,96618,362,59159,15592,1887,430,649,2804,904,20207,3465,430,264,3823,649,11,2737,6975,11,33811,11,323,3575,99246,627,18,13,3146,19841,93375,96618,1556,15592,1887,430,374,12207,810,25530,1109,279,1888,3823,20663,382,15836,6067,1005,5370,12823,311,11322,872,9021,11,2737,1473,16,13,3146,22333,21579,320,2735,33395,25,362,27084,315,15592,430,20682,12933,311,4048,505,828,323,7417,872,5178,927,892,627,17,13,3146,34564,21579,320,16931,33395,25,362,955,315,20187,430,5829,30828,14488,311,24564,6485,828,323,1304,20492,477,11429,627,18,13,3146,55381,11688,29225,320,45,12852,33395,25,578,5845,315,19002,311,3619,11,14532,11,323,7068,3823,4221,382,15836,14645,617,12387,8522,4028,5370,19647,11,2737,1473,16,13,3146,34126,54349,1821,96618,76074,11,5195,22103,11,323,50712,527,10507,315,15592,41503,4200,57619,430,649,2804,9256,1778,439,6376,66697,11,11889,6743,11,323,3339,6880,627,17,13,3146,1945,48698,96618,15592,6067,1093,5690,596,28900,18324,5557,477,5195,16912,6,17392,1665,18468,649,10765,6302,2949,5448,627,18,13,3146,54644,535,33527,96618,15592,41503,7526,649,24564,828,311,7168,6130,7865,11,11388,75559,11,323,1304,19075,627,19,13,3146,44474,1233,96618,15592,374,1511,304,29807,430,649,2804,9256,1778,439,14956,11,10873,11,323,2585,382,11458,11,15592,1101,25930,3892,10742,11,2737,1473,16,13,3146,12524,4185,16491,96618,1666,15592,5097,927,14348,9256,11,1063,7032,1253,3719,47166,11,6522,311,5199,7100,44219,627,17,13,3146,83652,323,14930,2136,96618,15592,6067,649,22313,6426,50183,422,814,527,16572,389,48761,828,477,6319,449,3230,26470,304,4059,627,18,13,3146,15712,54463,2857,96618,15592,41503,6067,649,387,20134,311,21516,8951,11,902,1436,617,15748,16296,382,1271,2686,1521,10742,11,12074,323,13707,527,3318,389,11469,1473,16,13,3146,849,21435,481,15592,320,55,15836,33395,25,66044,430,1520,12966,3619,1268,15592,6067,1304,11429,477,20492,627,17,13,3146,2654,3078,43821,16543,96618,19331,430,4639,15592,6067,311,15641,323,6013,311,39270,11374,477,8951,627,18,13,3146,35,8194,323,38366,2956,96618,56619,430,6106,828,374,17226,11,18740,11,323,1949,505,50183,382,28589,11,15592,706,279,4754,311,14110,553,5370,13878,315,1057,6439,11,719,433,596,7718,311,5603,1202,4500,449,28930,11,39242,11,323,264,5357,389,28118,1202,9669,323,11774,13],"total_duration":5672643300,"load_duration":253949700,"prompt_eval_count":27,"prompt_eval_duration":190542700,"eval_count":567,"eval_duration":3873491400}'

# %%
output=""
for i in response.iter_lines():
    if i:
        data = json.loads(i.decode('utf-8'))
        if 'response' in data:
            output += data['response']
        if data.get('done'):
            break
print(output)
# Out:
# Artificial Intelligence (AI) refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, decision-making, and perception. AI systems use algorithms and data to make decisions or predictions without being explicitly programmed.
#
# There are several types of AI, including:
#
# 1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition, language translation, or playing chess.
# 2. **General or Strong AI**: A hypothetical AI system that can perform any intellectual task that a human can, including learning, reasoning, and problem-solving.
# 3. **Superintelligence**: An AI system that is significantly more intelligent than the best human minds.
#
# AI systems use various techniques to achieve their goals, including:
#
# 1. **Machine Learning (ML)**: A subset of AI that enables machines to learn from data and improve their performance over time.
# 2. **Deep Learning (DL)**: A type of ML that uses neural networks to analyze complex data and make predictions or decisions.
# 3. **Natural Language Processing (NLP)**: The ability of computers to understand, interpret, and generate human language.
#
# AI technologies have numerous applications across various industries, including:
#
# 1. **Virtual Assistants**: Siri, Google Assistant, and Alexa are examples of AI-powered virtual assistants that can perform tasks such as setting reminders, sending messages, and making calls.
# 2. **Image Recognition**: AI systems like Facebook's facial recognition technology or Google Photos' automatic object detection can identify objects within images.
# 3. **Predictive Analytics**: AI-powered tools can analyze data to predict customer behavior, detect anomalies, and make recommendations.
# 4. **Robotics**: AI is used in robots that can perform tasks such as assembly, navigation, and control.
#
# However, AI also raises several concerns, including:
#
# 1. **Job Displacement**: As AI takes over routine tasks, some jobs may become obsolete, leading to significant economic disruption.
# 2. **Bias and Fairness**: AI systems can perpetuate biases if they are trained on biased data or designed with specific objectives in mind.
# 3. **Security Risks**: AI-powered systems can be vulnerable to cyber attacks, which could have severe consequences.
#
# To address these concerns, researchers and developers are working on developing:
#
# 1. **Explainable AI (XAI)**: Techniques that help humans understand how AI systems make decisions or predictions.
# 2. **Adversarial Training**: Methods that teach AI systems to recognize and respond to malicious inputs or attacks.
# 3. **Diverse and Representative Data**: Strategies that ensure data is diverse, representative, and free from biases.
#
# Overall, AI has the potential to revolutionize various aspects of our lives, but it's essential to approach its development with caution, accountability, and a focus on addressing its limitations and challenges.

# %%
import requests
url = 'http://localhost:11434/api/tags'
r = requests.get(url)
data = r.json()
data
# Out:
# {'models': [{'name': 'llama3.2:1b',
#    'model': 'llama3.2:1b',
#    'modified_at': '2026-02-22T15:43:46.9120807+05:30',
#    'size': 1321098329,
#    'digest': 'baf6a787fdffd633537aa2eb51cfd54cb93ff08e28040095462bb63daf552878',
#    'details': {'parent_model': '',
#     'format': 'gguf',
#     'family': 'llama',
#     'families': ['llama'],
#     'parameter_size': '1.2B',
#     'quantization_level': 'Q8_0'}}]}

# %%
for model in data['models']:
    print(model['name'])
# Out:
# llama3.2:1b
